# %% [markdown]
# # Packages and imports

# %%
# System things
import os

# Data manipulation
import pandas as pd
import numpy as np

# Data viz
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read in raw data from both groups

# %%
# Data dictionary and mapping to update col headers
data_dict = pd.read_csv('../data/data_dictionary.csv')
col_dict = dict(zip(data_dict['raw_col_name'], data_dict['col_name']))
data_dict[::20]
# Out:
#        raw_col_name              col_name  \
# 0         StartDate             StartDate
# 20   Demographics 3  years_experience_aba
# 40            LT-A9     low_low_high_high
# 60            MT-A2       med_low_med_low
# 80           MT-A22      med_high_low_med
# 100          HT-A15     high_med_high_med
#
#                                          question_text  \
# 0                                           Start Date
# 20   How many years of clinical experience do you h...
# 40   A client would like to eat a large amount of u...
# 60   A client would like to eat a large amount of u...
# 80   A client would like to eat a large amount of u...
# 100  A client would like to eat a large amount of u...
#
#                                   qualtrics_imoport_id data_type  \
# 0    {"ImportId":"startDate","timeZone":"America/De...  datetime
# 20                            {"ImportId":"QID6_TEXT"}       int
# 40                                {"ImportId":"QID26"}   boolean
# ...

# %%
# Behavior Analyst data
bx_data = pd.read_csv('../data/01_raw/all_bxanalyst_data.csv')
bx_df = bx_data.copy()
bx_df.head(10)
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                2022-03-01 09:40:41
# 3                                2022-03-02 12:56:47
# 4                                2022-03-05 08:16:01
# 5                                2022-03-05 11:38:56
# 6                                2022-03-01 04:41:52
# 7                                2022-03-01 06:13:28
# 8                                2022-03-09 15:09:41
# 9                                2022-03-09 17:21:48
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                2022-03-01 09:54:04                      0
# ...

# %%
# Gen Pop Data
gp_data = pd.read_csv('../raw/01_raw/all_genpop_data.csv')
gp_df = gp_data.copy()
gp_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/c5/vpx80swj4yb9ytlnrk8w2qnr0000gn/T/ipykernel_37478/1278728710.py in <module>
#       1 # Gen Pop Data
# ----> 2 gp_data = pd.read_csv('../raw/01_raw/all_genpop_data.csv')
#       3 gp_df = gp_data.copy()
#       4 gp_df.head(10)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
